# %% [markdown]
# # 01. SQL Server Schema Exploration & Dynamic Discovery
# This notebook dynamically reflects the SQL Server database schema using the SQLAlchemy Inspector. It inspects all tables, columns, indexes, and relationships. If the database is offline, it falls back to filesystem definitions.

# %%
import os
import sys
# Add project root to path
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../..'))

from database_exploration.core.schema_inspector import SchemaInspector
inspector = SchemaInspector()
print(f"Database Online Status: {inspector.is_connected()}")
print(f"Status Message: {inspector.status_message}")
# Out:
# Database Online Status: True
# Status Message: Successfully connected to SQL Server

# %% [markdown]
# ## 1. List All Database Tables

# %%
tables = inspector.get_all_tables()
print("Tables discovered:", tables)
# Out:
# [2026-05-29 18:07:43] INFO [db_exploration:schema_inspector.py:41] - Retrieved 51 tables from database: ['__EFMigrationsHistory', 'Address', 'ArticleBookmarks', 'AspNetRoleClaims', 'AspNetRoles', 'AspNetUserClaims', 'AspNetUserLogins', 'AspNetUserRoles', 'AspNetUsers', 'AspNetUserTokens', 'AutoBlockLogs', 'BoProductionRequestItems', 'BoProductionRequests', 'BoProductionRequestStatusHistories', 'BusinessOwnerPaymentInfos', 'BusinessOwnerProfile', 'Categories', 'ChatHistory', 'Complaints', 'CustomerCartItems', 'CustomerCarts', 'CustomerOrderItems', 'CustomerOrders', 'CustomerWishlistItems', 'CustomerWishlists', 'FAQs', 'KnowledgeArticles', 'LoginHistories', 'MaterialBasketItems', 'MaterialBaskets', 'MaterialOrderItems', 'MaterialOrders', 'NotificationPreferences', 'Notifications', 'OnboardingProgress', 'OrderStatusHistories', 'OtpCodes', 'PayoutRequests', 'ProductImages', 'ProductReviews', 'Products', 'RawMaterials', 'RefreshTokens', 'ReviewPhotos', 'Suppliers', 'SupportTickets', 'TicketAttachments', 'TicketMessages', 'Transactions', 'UserActionLogs', 'UserPreferences']
# Tables discovered: ['__EFMigrationsHistory', 'Address', 'ArticleBookmarks', 'AspNetRoleClaims', 'AspNetRoles', 'AspNetUserClaims', 'AspNetUserLogins', 'AspNetUserRoles', 'AspNetUsers', 'AspNetUserTokens', 'AutoBlockLogs', 'BoProductionRequestItems', 'BoProductionRequests', 'BoProductionRequestStatusHistories', 'BusinessOwnerPaymentInfos', 'BusinessOwnerProfile', 'Categories', 'ChatHistory', 'Complaints', 'CustomerCartItems', 'CustomerCarts', 'CustomerOrderItems', 'CustomerOrders', 'CustomerWishlistItems', 'CustomerWishlists', 'FAQs', 'KnowledgeArticles', 'LoginHistories', 'MaterialBasketItems', 'MaterialBaskets', 'MaterialOrderItems', 'MaterialOrders', 'NotificationPreferences', 'Notifications', 'OnboardingProgress', 'OrderStatusHistories', 'OtpCodes', 'PayoutRequests', 'ProductImages', 'ProductReviews', 'Products', 'RawMaterials', 'RefreshTokens', 'ReviewPhotos', 'Suppliers', 'SupportTickets', 'TicketAttachments', 'TicketMessages', 'Transactions', 'UserActionLogs', 'UserPreferences']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 2. Inspect Column Types for Key Tables

# %%
for table in ['interactions', 'products', 'raw_materials']:
    print(f"\n=== Schema for {table} ===")
    columns = inspector.get_table_columns(table)
    pks = inspector.get_primary_keys(table)
    print(f"Primary Keys: {pks}")
    for col in columns:
        print(f"  - {col['name']}: {col['type']} (Nullable: {col['nullable']})")

# %% [markdown]
# ## 3. Reflect Declarative Foreign Keys & Indexes

# %%
for table in ['interactions', 'products', 'raw_materials']:
    print(f"\n=== Indexes for {table} ===")
    indexes = inspector.get_indexes(table)
    for idx in indexes:
        print(f"  - Index: {idx['name']} on {idx['column_names']} (Unique: {idx['unique']})")
