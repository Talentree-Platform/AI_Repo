# %% [markdown]
# # 01. SQL Server Schema Exploration & Dynamic Discovery
# This notebook dynamically reflects the SQL Server database schema using the SQLAlchemy Inspector. It inspects all tables, columns, indexes, and relationships. If the database is offline, it falls back to filesystem definitions.

# %%
import os
import sys
# Add project root to path
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../..'))

from database_exploration.core.schema_inspector import SchemaInspector
inspector = SchemaInspector()
print(f"Database Online Status: {inspector.is_connected()}")
print(f"Status Message: {inspector.status_message}")
# Out:
# [2026-05-29 17:55:10] ERROR [db_exploration:db_connector.py:31] - SQL Server connection failed: (pymssql.exceptions.OperationalError) (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (db52715.databaseasp.net)\nNet-Lib error during Unknown error (10060)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (db52715.databaseasp.net)\nNet-Lib error during Unknown error (10060)\n')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# [2026-05-29 17:55:10] WARNING [db_exploration:schema_inspector.py:28] - SchemaInspector initialized in OFFLINE mode.
# Database Online Status: False
# Status Message: (pymssql.exceptions.OperationalError) (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (db52715.databaseasp.net)\nNet-Lib error during Unknown error (10060)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (db52715.databaseasp.net)\nNet-Lib error during Unknown error (10060)\n')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## 1. List All Database Tables

# %%
tables = inspector.get_all_tables()
print("Tables discovered:", tables)
# Out:
# [2026-05-29 15:34:58] WARNING [db_exploration:schema_inspector.py:37] - Offline: Cannot retrieve tables from SQL database. Suggesting local files.
# Tables discovered: []

# %% [markdown]
# ## 2. Inspect Column Types for Key Tables

# %%
for table in ['interactions', 'products', 'raw_materials']:
    print(f"\n=== Schema for {table} ===")
    columns = inspector.get_table_columns(table)
    pks = inspector.get_primary_keys(table)
    print(f"Primary Keys: {pks}")
    for col in columns:
        print(f"  - {col['name']}: {col['type']} (Nullable: {col['nullable']})")

# %% [markdown]
# ## 3. Reflect Declarative Foreign Keys & Indexes

# %%
for table in ['interactions', 'products', 'raw_materials']:
    print(f"\n=== Indexes for {table} ===")
    indexes = inspector.get_indexes(table)
    for idx in indexes:
        print(f"  - Index: {idx['name']} on {idx['column_names']} (Unique: {idx['unique']})")
